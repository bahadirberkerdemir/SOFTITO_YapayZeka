# %%
print("Python Öğrenciyorum")

ad= 'Bahadır Berk '
soyad='Erdemir'
print(ad+soyad)
print(5, 'Kişiyiz')
print('ben ',(10*1.9),' yaşındayım')
# Out:
# Python Öğrenciyorum
# Bahadır Berk Erdemir

# %%
text="bahadir"
print(text.upper()) #text'in bütün harfllerini büyütür
'''
Bahadır Berk Erdemir 19 yaşındadır ve Bandırma'da yaşamaktadır.
'''
# Out:
# BAHADIR

# %%
sehir = "Bandırma"
print(sehir)

puan=50
print(puan)
puan=75
print(puan)
# Out:
# Bandırma

# %%
sayi= 21
onda= 3.14
text= "Bahadir"
saat_erken_mi= True

print(f"sayi: {type(sayi)}, onda: {type(onda)}") 
print(f"text: {type(text)}, saat_erken_mi: {type(saat_erken_mi)}")
# Out:
# sayi: <class 'int'>, onda: <class 'float'>
# text: <class 'str'>, saat_erken_mi: <class 'bool'>

# %%
print(15+4,15*4,15/4,15-4,17%5,2**8)
# Out:
# 19 60 3.75 11 2 256

# %%
isim = input("ad gir: ")
yas = int(input("yas gir: "))
print(f"merhaba {isim}, 10 yıl sonraki yasin= {yas+10}")
# Out:
# merhaba baho, 10 yıl sonraki yasin= 29

# %%
a = 8
b = 12
numb= int(input("sayi gir: "))
print(f"a<b: {a<b}, a>b: {a>b}, a=b: {a==b}, Senin sayın 100 mü? {100==numb}")
# Out:
# a<b: True, a>b: False, a=b: False, Senin sayın 100 mü? True

# %%
age=22
ogrenci_mi=False
ogrenci_mi and age>18
# Out:
# False

# %%
notun= int(input("notunu gir"))

if notun>50:
    print("notun pozitif ve geçtin")
elif notun>0:
    print("notun pozitif ama kaldın")
elif notun<0:
    print("notun negatif ve kaldın")
else:
    print("Sıfır alıp kaldın")
# Out:
# notun pozitif ve geçtin

# %%
ilkad= "Bahadir "
ortaad= "Berk "
soyisim= "Erdemir"

tamad= ilkad+ortaad+soyisim
print(f"adın {len(tamad)} karakter, {tamad.upper()}, {tamad.lower()}")
# Out:
# adın 20 karakter, BAHADIR BERK ERDEMIR, bahadir berk erdemir

# %%
def carp(a,b):
    return a*b
def kare(a):
    return a**2

x= int(input("x gir"))
y= int(input("y gir"))
z= int(input("z gir"))

carpim= carp(x,y)
zkare= kare(z)

print(f"x çarpı y= {carpim}, z'nin karesi= {zkare}")
# Out:
# x çarpı y= 24, z'nin karesi= 81
